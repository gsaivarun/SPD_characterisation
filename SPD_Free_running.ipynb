# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import csv
import numpy as np
import matplotlib.pyplot as plt

def calculate_average(filename):
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        data = list(reader)
    column_1 = data[6:]
    photons = [int(row[0]) for row in column_1]
    return round(sum(photons) / len(photons), 2)  # Round off to 2 decimal places

v2_1us = calculate_average('00285_2v_1us.csv')
v2_2us = calculate_average('00285_2v_2us.csv')
v2_5us = calculate_average('00285_2v_5us.csv')
v2_10us = calculate_average('00285_2v_10us.csv')
v2_20us = calculate_average('00285_2v_20us.csv')
v2_50us = calculate_average('00285_2v_50us.csv')
v2_100us = calculate_average('00285_2v_100us.csv')
v2_130us = calculate_average('00285_2v_130us.csv')
v2_150us = calculate_average('00285_2v_150us.csv')
v2_200us = calculate_average('00285_2v_200us.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v2 = [v2_1us, v2_2us, v2_5us, v2_10us, v2_20us, v2_50us, v2_100us, v2_130us, v2_150us, v2_200us]
plt.plot(x, y_v2, label=f'v2', color='b', marker = 's')

v4_1us = calculate_average('00285_4v_1us.csv')
v4_2us = calculate_average('00285_4v_2us.csv')
v4_5us = calculate_average('00285_4v_5us.csv')
v4_10us = calculate_average('00285_4v_10us.csv')
v4_20us = calculate_average('00285_4v_20us.csv')
v4_50us = calculate_average('00285_4v_50us.csv')
v4_100us = calculate_average('00285_4v_100us.csv')
v4_130us = calculate_average('00285_4v_130us.csv')
v4_150us = calculate_average('00285_4v_150us.csv')
v4_200us = calculate_average('00285_4v_200us.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v4 = [v4_1us, v4_2us, v4_5us, v4_10us, v4_20us, v4_50us, v4_100us, v4_130us, v4_150us, v4_200us]
plt.plot(x, y_v4, label=f'v4', color='g', marker = 'o')

v5_1us = calculate_average('00285_5v_1us.csv')
v5_2us = calculate_average('00285_5v_2us.csv')
v5_5us = calculate_average('00285_5v_5us.csv')
v5_10us = calculate_average('00285_5v_10us.csv')
v5_20us = calculate_average('00285_5v_20us.csv')
v5_50us = calculate_average('00285_5v_50us.csv')
v5_100us = calculate_average('00285_5v_100us.csv')
v5_130us = calculate_average('00285_5v_130us.csv')
v5_150us = calculate_average('00285_5v_150us.csv')
v5_200us = calculate_average('00285_5v_200us.csv')

x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v5 = [v5_1us, v5_2us, v5_5us, v5_10us, v5_20us, v5_50us, v5_100us, v5_130us, v5_150us, v5_200us]
plt.plot(x, y_v5, label=f'v5', color='r', marker='v')
plt.xlabel('Hold off Time (us)')
plt.ylabel('DCR')
plt.yscale('log')
plt.title('DCR vs Hold Off- FREE RUNNING')
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import csv
import numpy as np
import matplotlib.pyplot as plt

def calculate_average(filename):
    with open(filename, 'r') as file:
        reader = csv.reader(file)
        data = list(reader)
    column_1 = data[6:]
    photons = [int(row[0]) for row in column_1]
    return round(sum(photons) / len(photons), 2)  # Round off to 2 decimal places

v2_1us = calculate_average('00285_2v_1us_10hz.csv')
v2_2us = calculate_average('00285_2v_2us_10hz.csv')
v2_5us = calculate_average('00285_2v_5us_10hz.csv')
v2_10us = calculate_average('00285_2v_10us_10hz.csv')
v2_20us = calculate_average('00285_2v_20us_10hz.csv')
v2_50us = calculate_average('00285_2v_50us_10hz.csv')
v2_100us = calculate_average('00285_2v_100us_10hz.csv')
v2_130us = calculate_average('00285_2v_130us_10hz.csv')
v2_150us = calculate_average('00285_2v_150us_10hz.csv')
v2_200us = calculate_average('00285_2v_200us_10hz.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v2 = [v2_1us, v2_2us, v2_5us, v2_10us, v2_20us, v2_50us, v2_100us, v2_130us, v2_150us, v2_200us]
plt.plot(x, y_v2, label=f'v2', color='b', marker = 's')

v4_1us = calculate_average('00285_4v_1us_10hz.csv')
v4_2us = calculate_average('00285_4v_2us_10hz.csv')
v4_5us = calculate_average('00285_4v_5us_10hz.csv')
v4_10us = calculate_average('00285_4v_10us_10hz.csv')
v4_20us = calculate_average('00285_4v_20us_10hz.csv')
v4_50us = calculate_average('00285_4v_50us_10hz.csv')
v4_100us = calculate_average('00285_4v_100us_10hz.csv')
v4_130us = calculate_average('00285_4v_130us_10hz.csv')
v4_150us = calculate_average('00285_4v_150us_10hz.csv')
v4_200us = calculate_average('00285_4v_200us_10hz.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v4 = [v4_1us, v4_2us, v4_5us, v4_10us, v4_20us, v4_50us, v4_100us, v4_130us, v4_150us, v4_200us]
plt.plot(x, y_v4, label=f'v4', color='g', marker = 'o')

v6_1us = calculate_average('00285_6v_1us_10hz.csv')
v6_2us = calculate_average('00285_6v_2us_10hz.csv')
v6_5us = calculate_average('00285_6v_5us_10hz.csv')
v6_10us = calculate_average('00285_6v_10us_10hz.csv')
v6_20us = calculate_average('00285_6v_20us_10hz.csv')
v6_50us = calculate_average('00285_6v_50us_10hz.csv')
v6_100us = calculate_average('00285_6v_100us_10hz.csv')
v6_130us = calculate_average('00285_6v_130us_10hz.csv')
v6_150us = calculate_average('00285_6v_150us_10hz.csv')
v6_200us = calculate_average('00285_6v_200us_10hz.csv')

x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y_v6 = [v6_1us, v6_2us, v6_5us, v6_10us, v6_20us, v6_50us, v6_100us, v6_130us, v6_150us, v6_200us]
plt.plot(x, y_v6, label=f'v5', color='r', marker='v')
plt.xlabel('Hold off Time (us)')

#v7_1us = calculate_average('00285_7v_1us_10hz.csv')
#v7_2us = calculate_average('00285_7v_2us_10hz.csv')
#v7_5us = calculate_average('00285_7v_5us_10hz.csv')
#v7_10us = calculate_average('00285_7v_10us_10hz.csv')
#v7_20us = calculate_average('00285_7v_20us_10hz.csv')
#v7_50us = calculate_average('00285_7v_50us_10hz.csv')
#v7_100us = calculate_average('00285_7v_100us_10hz.csv')
#v7_130us = calculate_average('00285_7v_130us_10hz.csv')
#v7_150us = calculate_average('00285_7v_150us_10hz.csv')
#v7_200us = calculate_average('00285_7v_200us_10hz.csv')

#x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
#y_v7 = [v7_1us, v7_2us, v7_5us, v7_10us, v7_20us, v7_50us, v7_100us, v7_130us, v7_150us, v7_200us]
#plt.plot(x, y_v7, label=f'v7', color='yellow', marker='<')

v2__1us = calculate_average('00285_2v_1us_64hz.csv')
v2__2us = calculate_average('00285_2v_2us_64hz.csv')
v2__5us = calculate_average('00285_2v_5us_64hz.csv')
v2__10us = calculate_average('00285_2v_10us_64hz.csv')
v2__20us = calculate_average('00285_2v_20us_64hz.csv')
v2__50us = calculate_average('00285_2v_50us_64hz.csv')
v2__100us = calculate_average('00285_2v_100us_64hz.csv')
v2__130us = calculate_average('00285_2v_130us_64hz.csv')
v2__150us = calculate_average('00285_2v_150us_64hz.csv')
v2__200us = calculate_average('00285_2v_200us_64hz.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y__v2 = [v2__1us, v2__2us, v2__5us, v2__10us, v2__20us, v2__50us, v2__100us, v2__130us, v2__150us, v2__200us]
plt.plot(x, y__v2, linestyle='dashed', label=f'v2', color='b', marker = 's')

v4__1us = calculate_average('00285_4v_1us_64hz.csv')
v4__2us = calculate_average('00285_4v_2us_64hz.csv')
v4__5us = calculate_average('00285_4v_5us_64hz.csv')
v4__10us = calculate_average('00285_4v_10us_64hz.csv')
v4__20us = calculate_average('00285_4v_20us_64hz.csv')
v4__50us = calculate_average('00285_4v_50us_64hz.csv')
v4__100us = calculate_average('00285_4v_100us_64hz.csv')
v4__130us = calculate_average('00285_4v_130us_64hz.csv')
v4__150us = calculate_average('00285_4v_150us_64hz.csv')
v4__200us = calculate_average('00285_4v_200us_64hz.csv')


x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y__v4 = [v4__1us, v4__2us, v4__5us, v4__10us, v4__20us, v4__50us, v4__100us, v4__130us, v4__150us, v4__200us]
plt.plot(x, y__v4, linestyle='dashed', label=f'v4', color='g', marker = 'o')

v6__1us = calculate_average('00285_6v_1us_64hz.csv')
v6__2us = calculate_average('00285_6v_2us_64hz.csv')
v6__5us = calculate_average('00285_6v_5us_64hz.csv')
v6__10us = calculate_average('00285_6v_10us_64hz.csv')
v6__20us = calculate_average('00285_6v_20us_64hz.csv')
v6__50us = calculate_average('00285_6v_50us_64hz.csv')
v6__100us = calculate_average('00285_6v_100us_64hz.csv')
v6__130us = calculate_average('00285_6v_130us_64hz.csv')
v6__150us = calculate_average('00285_6v_150us_64hz.csv')
v6__200us = calculate_average('00285_6v_200us_64hz.csv')

x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
y__v6 = [v6__1us, v6__2us, v6__5us, v6__10us, v6__20us, v6__50us, v6__100us, v6__130us, v6__150us, v6__200us]
plt.plot(x, y__v6, linestyle='dashed', label=f'v5', color='r', marker='v')
plt.xlabel('Hold off Time (us)')

#v7__1us = calculate_average('00285_7v_1us_64hz.csv')
#v7__2us = calculate_average('00285_7v_2us_64hz.csv')
#v7__5us = calculate_average('00285_7v_5us_64hz.csv')
#v7__10us = calculate_average('00285_7v_10us_64hz.csv')
#v7__20us = calculate_average('00285_7v_20us_64hz.csv')
#v7__50us = calculate_average('00285_7v_50us_64hz.csv')
#v7__100us = calculate_average('00285_7v_100us_64hz.csv')
#v7__130us = calculate_average('00285_7v_130us_64hz.csv')
#v7__150us = calculate_average('00285_7v_150us_64hz.csv')
#v7__200us = calculate_average('00285_7v_200us_64hz.csv')

#x = [1, 2, 5, 10, 20, 50, 100, 130, 150, 200]
#y__v7 = [v7__1us, v7__2us, v7__5us, v7__10us, v7__20us, v7__50us, v7__100us, v7__130us, v7__150us, v7__200us]
#plt.plot(x, y__v7, linestyle='dashed', label=f'v7', color='yellow', marker='<')

plt.xlabel('Hold off Time (us)')
plt.xscale('log')
plt.ylabel('DCR')
plt.yscale('log')
plt.title('DCR vs Hold Off - GATED MODE')
plt.grid(True)
plt.legend()
plt.show()
